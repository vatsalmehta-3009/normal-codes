# %%
import pandas as pd

# %%
df = pd.read_csv('corona_csv.csv', encoding='unicode-escape',index_col=0)
#skiprows parameter skips rows from start.
df.head()
# Out:
#   Country, Other  Total Cases New Cases Total Deaths  New Deaths  \
# #
# 1            USA  3,45,40,866        21     6,20,250         1.0
# 2          India  3,04,32,670    22,093     3,99,720       245.0
# 3         Brazil  1,85,59,164       NaN     5,18,246         NaN
# 4         France    57,75,301       NaN     1,11,082         NaN
# 5         Russia    55,38,142    23,543     1,35,886       672.0
#
#   Total Recovered New Recovered Active Cases Serious, Critical  \
# #
# 1     2,90,26,688           NaN    48,93,928             3,891
# 2     2,94,98,619        17,097     5,34,331             8,944
# 3     1,68,58,632           NaN    11,82,286             8,318
# 4       56,18,885           NaN       45,334             1,204
# 5       50,17,321        16,928     3,84,935             2,300
#
#   Tot Cases/ 1M pop Deaths/ 1M pop   Total Tests Tests/ 1M pop      Population
# #
# 1          1,03,747          1,863  50,61,59,128     15,20,297    33,29,34,343
# ...

# %%
#For Reading text files(read_table) 
#df = pd.read_table("corona_textfile.txt")

# %%
#WE CAN SPECIFY SHEET OF EXCEL FILE
df = pd.read_excel('corona_excel.xlsx',sheet_name='Sheet1',index_col=0)

# %%
#MAKING A COLUMN AS INDEX OF DATAFRAME
df.set_index('Country, Other',inplace=True)

# %%
#RESETTING INDEX
df.reset_index()
# Out:
#        Country, Other  Total Cases  New Cases  Total Deaths  New Deaths  \
# 0                 USA     34540866       21.0      620250.0         1.0
# 1               India     30432670    22093.0      399720.0       245.0
# 2              Brazil     18559164        NaN      518246.0         NaN
# 3              France      5775301        NaN      111082.0         NaN
# 4              Russia      5538142    23543.0      135886.0       672.0
# ..                ...          ...        ...           ...         ...
# 217           Vanuatu            4        NaN           1.0         NaN
# 218  Marshall Islands            4        NaN           NaN         NaN
# 219             Samoa            3        NaN           NaN         NaN
# 220      Saint Helena            2        NaN           NaN         NaN
# 221        Micronesia            1        NaN           NaN         NaN
#
#      Total Recovered  New Recovered  Active Cases  Serious, Critical  \
# ...

# %%
from sklearn import datasets

# %%
#THIS IS DATASET FOR UNSUPERVISED LEARNING
table = datasets.make_circles()

# %%
#THIS IS DATASET FOR SUPERVISED LEARNING
table_ = datasets.load_boston()
table_.keys()
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename'])

# %%
df_ = pd.DataFrame(data = table_['data'],columns = table_['feature_names'])

# %%
df_.dtypes
# Out:
# CRIM       float64
# ZN         float64
# INDUS      float64
# CHAS       float64
# NOX        float64
# RM         float64
# AGE        float64
# DIS        float64
# RAD        float64
# TAX        float64
# PTRATIO    float64
# B          float64
# LSTAT      float64
# dtype: object

# %%
df_.describe(include = 'all', percentiles=[0.1,0.2,0.9])
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 10%      0.038195    0.000000    2.910000    0.000000    0.427000    5.593500
# 20%      0.064170    0.000000    4.390000    0.000000    0.442000    5.837000
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 90%     10.753000   42.500000   19.580000    0.000000    0.713000    7.151500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# ...

# %%
df_.drop_duplicates(inplace=True)
df_.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
#default axis is rows(0).
df_.drop(list(range(0,len(df_),2)))
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 5    0.02985   0.0   2.18   0.0  0.458  6.430  58.7  6.0622  3.0  222.0
# 7    0.14455  12.5   7.87   0.0  0.524  6.172  96.1  5.9505  5.0  311.0
# 9    0.17004  12.5   7.87   0.0  0.524  6.004  85.9  6.5921  5.0  311.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 497  0.26838   0.0   9.69   0.0  0.585  5.794  70.6  2.8927  6.0  391.0
# 499  0.17783   0.0   9.69   0.0  0.585  5.569  73.5  2.3999  6.0  391.0
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 1       17.8  396.90   9.14
# 3       18.7  394.63   2.94
# ...

# %%
import numpy as np

# %%
m1 = np.matrix([[1,4],[2,3]])
m1
# Out:
# matrix([[1, 4],
#         [2, 3]])

# %%
m1.conjugate()
# Out:
# matrix([[1, 4],
#         [2, 3]])

# %%
m1.I
# Out:
# matrix([[-0.6,  0.8],
#         [ 0.4, -0.2]])

# %%
m1.transpose()
# Out:
# matrix([[1, 2],
#         [4, 3]])

# %%
m2 = np.matrix("0 0 0 ; 1 1 1 ; 2 2 2")

# %%
m2.reshape(1,9)
# Out:
# matrix([[0, 0, 0, 1, 1, 1, 2, 2, 2]])

# %%
a = m1.getI()

# %%
m1 * a
# Out:
# matrix([[ 1.00000000e+00,  0.00000000e+00],
#         [-1.11022302e-16,  1.00000000e+00]])

# %%
m1
# Out:
# matrix([[1, 4],
#         [2, 3]])

# %%
for i in m1:
    print(i)
# Out:
# [[1 4]]
# [[2 3]]

# %%
# !pip install klib

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_23631/1908050613.py in <module>
# ----> 1 klib
#
# NameError: name 'klib' is not defined
