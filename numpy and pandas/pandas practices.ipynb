# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
os.getcwd()
# Out:
# '/home/lenovo/Jupyter books/numpy and pandas'

# %%
df = pd.read_excel('StudentsPerformance.xlsx', index_col=0, sheet_name='StudentsPerformance')
df.head(2)
# Out:
#    gender race/ethnicity parental level of education     lunch  \
# 1  female        group B           bachelor's degree  standard
# 2  female        group C                some college  standard
#
#   test preparation course  math score  reading score  writing score
# 1                    none          72             72             74
# 2               completed          69             90             88

# %%
df['race/ethnicity'].unique()
# Out:
# array(['group B', 'group C', 'group A', 'group D', 'group E'],
#       dtype=object)

# %%
df['race/ethnicity'].value_counts().index
# Out:
# Index(['group C', 'group D', 'group B', 'group E', 'group A'], dtype='object')

# %%
df[(df['writing score'] < 80) & (df['reading score']>50)]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 1    female        group B           bachelor's degree      standard
# 4      male        group A          associate's degree  free/reduced
# 5      male        group C                some college      standard
# 6    female        group B          associate's degree      standard
# 9      male        group D                 high school  free/reduced
# ..      ...            ...                         ...           ...
# 994  female        group D           bachelor's degree  free/reduced
# 995    male        group A                 high school      standard
# 997    male        group C                 high school  free/reduced
# 998  female        group C                 high school  free/reduced
# 999  female        group D                some college      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df[(df['reading score'] < df['reading score'].mean())][['gender','test preparation course']]
# Out:
#      gender test preparation course
# 4      male                    none
# 8      male                    none
# 9      male               completed
# 10   female                    none
# 11     male                    none
# ..      ...                     ...
# 986    male                    none
# 987  female                    none
# 989  female                    none
# 995    male                    none
# 997    male                    none
#
# [487 rows x 2 columns]

# %%
df[(df['parental level of education'] == "master's degree")]['math score'].min()
# Out:
# 40

# %%
df.loc[9:14  ,['race/ethnicity','parental level of education']]
# Out:
#    race/ethnicity parental level of education
# 9         group D                 high school
# 10        group B                 high school
# 11        group C          associate's degree
# 12        group D          associate's degree
# 13        group B                 high school
# 14        group A                some college

# %%
df.loc[[755,761,764,765],["parental level of education","lunch"]]
# Out:
#     parental level of education         lunch
# 755          associate's degree  free/reduced
# 761                 high school  free/reduced
# 764                 high school      standard
# 765                some college      standard
