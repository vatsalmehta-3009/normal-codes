# %%
import pandas as pd
import numpy as np

# %%
f = open(r'arihantdata.txt','r')
data = f.readlines()
f.close()

# %%
ls = []
for i in data:
    ls.append(i.split('-'))

# %%
pd.DataFrame(ls,columns=['name','vairagya_reason','age','lanchan','dev/devi'])
# Out:
#                            name       vairagya_reason                  age  \
# 0            १) श्री ऋषभनाथ जी    नीलांजना की मृत्यु     84 लाख पूर्व वर्ष
# 1           २) श्री अजितनाथ जी         बिजली चमकने से    72 लाख पूर्व वर्ष
# 2          ३) श्री सम्भवनाथ जी          मेघ देखने से     60 लाख पूर्व वर्ष
# 3      ४) श्री अभिनन्दन नाथ जी         मेघों का विघटन    50 लाख पूर्व वर्ष
# 4          ५) श्री सुमतिनाथ जी             जाति स्मरण   40 लाख पूर्व वर्ष
# 5      ६) श्री पदमप्रभु नाथ जी             जाति स्मरण    30 लाख पूर्व वर्ष
# 6     ७) श्री सुपार्श्व नाथ जी             जाति स्मरण   20 लाख पूर्व वर्ष
# 7   ८) श्री चन्द्रप्रभु नाथ जी                 दर्पण    10 लाख पूर्व वर्ष
# 8     ९) श्री पुष्पदन्त नाथ जी           उल्कापात से     2 लाख पूर्व वर्ष
# 9          १०) श्री शीतलनाथ जी             हिमनाश से      1 लाख पूर्व वर्ष
# 10     ११) श्री श्रेयांसनाथ जी              पतझड़ से          84 लाख वर्ष
# 11   १२) श्री वासुपूज्य नाथ जी             जाति स्मरण         72 लाख वर्ष
# 12         १३) श्री विमलनाथ जी               ओस विघटन         60 लाख वर्ष
# 13        १४) श्री अनन्तनाथ जी            उल्कापात से          30 लाख वर्ष
# 14         १५) श्री धर्मनाथ जी           उल्कापात से          10 लाख वर्ष
# 15        १६) श्री शांतिनाथ जी    जाति स्मरण (दर्पण)            1 लाख वर्ष
# 16       १७) श्री कुन्थुनाथ जी             जाति स्मरण        95 हजार वर्ष
# 17          १८) श्री अरहनाथ जी           मेघ फटने से         84 हजार वर्ष
# 18        १९) श्री मल्लिनाथ जी                 ताड़ित        55 हजार वर्ष
# 19   २०) श्री मुनिसुव्रतनाथ जी             जाति स्मरण         30 हजार वर्ष
# 20                           \n                  None                 None
# 21          २१) श्री नमिनाथ जी             जाति स्मरण        10 हजार वर्ष
# 22                           \n                  None                 None
# 23         २२) श्री नेमिनाथ जी      पशुओं का क्रन्दन           1 हजार वर्ष
# 24                           \n                  None                 None
# 25      २३) श्री पार्श्वनाथ जी             जाति स्मरण            100 वर्ष
# 26                           \n                  None                 None
# 27   २४) श्री महावीर स्वामी जी             जाति स्मरण             72 वर्ष
#
#                 lanchan                            dev/devi
# 0                  बैल          गोमुख देव/चक्रेश्वरी देवी\n
# 1                  हाथी           महायक्ष देव/रोहिणी देवी\n
# 2          अश्व (घोड़ा)       त्रिमुख देव/ प्रज्ञप्तिदेवी\n
# 3                 बंदर    यक्षेश्वर देव/व्रजश्रृंखला देवी\n
# 4                 चकवा       तुम्बरू देव/ पुरुषदत्ता देवी\n
# 5                  कमल             कुसुमदेव/ मनोवेगा देवी\n
# 6    साथिया (स्वस्तिक)              वरनन्दि देव/काली देवी\n
# 7             चन्द्रमा         विजय देव/ज्वालामालिनी देवी\n
# 8                   मगर             अजित देव/महाकाली देवी\n
# 9            कल्पवृक्ष         ब्रह्मेश्वर देव/मानवी देवी\n
# 10               गैंडा                कुमार देव/गौरी देवी\n
# 11               भैंसा              षणमुखदेव/गांधारी देवी\n
# 12                शूकर             पाताल देव/ वैरोटी देवी\n
# 13                सेही            किन्नर देव/अनंतमती देवी\n
# 14             वज्रदंड            किंपुरुष देव/मानसी देवी\n
# 15          मृग (हिरण)            गरुड़ देव/महामानसी देवी\n
# 16                बकरा                गंधर्व देव/जया देवी\n
# 17                मछली             महेंद्र देव/विजया देवी\n
# 18                 कलश             कुबेर देव/अपराजितादेवी\n
# 19                कछुआ           वरुण देव /बहुरूपिणी देवी\n
# 20                 None                                None
# 21              नीलकमल       विधुत्प्रभ देव/चामुण्डी देवी\n
# 22                 None                                None
# 23                 शंख         सर्वाण्हदेव/कुषमाण्डी देवी\n
# 24                 None                                None
# 25                सर्प        धरणेन्द्र देव/पद्मावती देवी\n
# 26                 None                                None
# 27                सिंह           मातंग देव/सिद्धायनी देवी\n

# %%
ls = np.array(ls)
# Out:
# ['१) श्री ऋषभनाथ जी ',
#  ' नीलांजना की मृत्यु ',
#  ' 84 लाख पूर्व वर्ष',
#  ' बैल ',
#  ' गोमुख देव/चक्रेश्वरी देवी\n']

# %%
pd.DataFrame(ls.T,columns = ['name','b','c','d','e'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_39460/2424755916.py in <module>
# ----> 1 pd.DataFrame(ls.T,columns = ['name','b','c','d','e'])
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     670                 )
#     671             else:
# --> 672                 mgr = ndarray_to_mgr(
#     673                     data,
#     674                     index,
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/internals/construction.py in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     322     )
#     323
# --> 324     _check_values_indices_shape_match(values, index, columns)
#     325
#     326     if typ == "array":
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/internals/construction.py in _check_values_indices_shape_match(values, index, columns)
#     391         passed = values.shape
#     392         implied = (len(index), len(columns))
# --> 393         raise ValueError(f"Shape of passed values is {passed}, indices imply {implied}")
#     394
#     395
#
# ValueError: Shape of passed values is (28, 1), indices imply (28, 5)

# %%
ls.T
# Out:
# array([list(['१) श्री ऋषभनाथ जी ', ' नीलांजना की मृत्यु ', ' 84 लाख पूर्व वर्ष', ' बैल ', ' गोमुख देव/चक्रेश्वरी देवी\n']),
#        list(['२) श्री अजितनाथ जी ', ' बिजली चमकने से', ' 72 लाख पूर्व वर्ष', ' हाथी', ' महायक्ष देव/रोहिणी देवी\n']),
#        list(['३) श्री सम्भवनाथ जी ', ' मेघ देखने से ', ' 60 लाख पूर्व वर्ष', ' अश्व (घोड़ा)', ' त्रिमुख देव/ प्रज्ञप्तिदेवी\n']),
#        list(['४) श्री अभिनन्दन नाथ जी ', ' मेघों का विघटन', ' 50 लाख पूर्व वर्ष', ' बंदर ', ' यक्षेश्वर देव/व्रजश्रृंखला देवी\n']),
#        list(['५) श्री सुमतिनाथ जी ', ' जाति स्मरण', ' 40 लाख पूर्व वर्ष ', ' चकवा ', ' तुम्बरू देव/ पुरुषदत्ता देवी\n']),
#        list(['६) श्री पदमप्रभु नाथ जी ', ' जाति स्मरण', ' 30 लाख पूर्व वर्ष', ' कमल ', ' कुसुमदेव/ मनोवेगा देवी\n']),
#        list(['७) श्री सुपार्श्व नाथ जी ', ' जाति स्मरण', ' 20 लाख पूर्व वर्ष ', ' साथिया (स्वस्तिक) ', ' वरनन्दि देव/काली देवी\n']),
#        list(['८) श्री चन्द्रप्रभु नाथ जी ', ' दर्पण ', '10 लाख पूर्व वर्ष ', ' चन्द्रमा ', ' विजय देव/ज्वालामालिनी देवी\n']),
#        list(['९) श्री पुष्पदन्त नाथ जी ', ' उल्कापात से ', ' 2 लाख पूर्व वर्ष ', ' मगर', ' अजित देव/महाकाली देवी\n']),
#        list(['१०) श्री शीतलनाथ जी ', ' हिमनाश से ', ' 1 लाख पूर्व वर्ष', ' कल्पवृक्ष ', ' ब्रह्मेश्वर देव/मानवी देवी\n']),
#        list(['११) श्री श्रेयांसनाथ जी ', ' पतझड़ से ', ' 84 लाख वर्ष ', ' गैंडा ', ' कुमार देव/गौरी देवी\n']),
#        list(['१२) श्री वासुपूज्य नाथ जी ', ' जाति स्मरण', ' 72 लाख वर्ष ', ' भैंसा ', ' षणमुखदेव/गांधारी देवी\n']),
#        list(['१३) श्री विमलनाथ जी ', ' ओस विघटन', '60 लाख वर्ष ', ' शूकर ', ' पाताल देव/ वैरोटी देवी\n']),
#        list(['१४) श्री अनन्तनाथ जी ', ' उल्कापात से', ' 30 लाख वर्ष', ' सेही ', ' किन्नर देव/अनंतमती देवी\n']),
#        list(['१५) श्री धर्मनाथ जी ', ' उल्कापात से ', ' 10 लाख वर्ष ', ' वज्रदंड ', ' किंपुरुष देव/मानसी देवी\n']),
#        list(['१६) श्री शांतिनाथ जी ', ' जाति स्मरण (दर्पण) ', ' 1 लाख वर्ष', ' मृग (हिरण) ', ' गरुड़ देव/महामानसी देवी\n']),
#        list(['१७) श्री कुन्थुनाथ जी ', ' जाति स्मरण', ' 95 हजार वर्ष ', ' बकरा ', ' गंधर्व देव/जया देवी\n']),
#        list(['१८) श्री अरहनाथ जी ', ' मेघ फटने से ', ' 84 हजार वर्ष ', ' मछली ', ' महेंद्र देव/विजया देवी\n']),
#        list(['१९) श्री मल्लिनाथ जी ', ' ताड़ित', ' 55 हजार वर्ष ', ' कलश ', ' कुबेर देव/अपराजितादेवी\n']),
#        list(['२०) श्री मुनिसुव्रतनाथ जी ', ' जाति स्मरण', ' 30 हजार वर्ष', ' कछुआ ', ' वरुण देव /बहुरूपिणी देवी\n']),
#        list(['\n']),
#        list(['२१) श्री नमिनाथ जी ', ' जाति स्मरण', '10 हजार वर्ष ', ' नीलकमल ', ' विधुत्प्रभ देव/चामुण्डी देवी\n']),
#        list(['\n']),
#        list(['२२) श्री नेमिनाथ जी ', ' पशुओं का क्रन्दन ', ' 1 हजार वर्ष', ' शंख ', ' सर्वाण्हदेव/कुषमाण्डी देवी\n']),
#        list(['\n']),
#        list(['२३) श्री पार्श्वनाथ जी ', ' जाति स्मरण', ' 100 वर्ष ', ' सर्प ', ' धरणेन्द्र देव/पद्मावती देवी\n']),
#        list(['\n']),
#        list(['२४) श्री महावीर स्वामी जी ', ' जाति स्मरण', ' 72 वर्ष ', ' सिंह ', ' मातंग देव/सिद्धायनी देवी\n'])],
#       dtype=object)
